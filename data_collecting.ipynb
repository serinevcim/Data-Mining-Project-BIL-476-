# %%
import os
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import (
    ElementClickInterceptedException,
    ElementNotInteractableException,
    NoSuchElementException,
    UnexpectedAlertPresentException,
    TimeoutException,
)

# %% [markdown]
# Collect every style page link from the https://www.wikiart.org/en/paintings-by-style website.

# %%
# Start the browser
driver = webdriver.Chrome()
driver.get("https://www.wikiart.org/en/paintings-by-style")
time.sleep(5)  # wait for page to load, increase if needed

# Get all <ul> with the desired class
style_list = driver.find_elements(By.CSS_SELECTOR, 'ul.dictionaries-list li.dottedItem a')

print(f"Found {len(style_list)} style links:\n")

style_urls = []
# Print the names and URLs
for link in style_list:
    name = link.text.strip()
    href = link.get_attribute("href")
    print(f"{name} - {href}")
    if href:  # skip if None
        style_urls.append(href)

driver.quit()
# Out:
# Found 218 style links:
#
# Early Dynastic 2 - https://www.wikiart.org/en/paintings-by-style/early-dynastic-period
# Old Kingdom 1 - https://www.wikiart.org/en/paintings-by-style/old-kingdom
# Middle Kingdom 9 - https://www.wikiart.org/en/paintings-by-style/middle-kingdom
# New Kingdom 114 - https://www.wikiart.org/en/paintings-by-style/new-kingdom
# Amarna 12 - https://www.wikiart.org/en/paintings-by-style/amarna
# 3rd Intermediate Period 16 - https://www.wikiart.org/en/paintings-by-style/3rd-intermediate-period
# Late Period 4 - https://www.wikiart.org/en/paintings-by-style/late-period
# Ptolemaic 4 - https://www.wikiart.org/en/paintings-by-style/ptolemaic
# 2nd Intermediate Period 1 - https://www.wikiart.org/en/paintings-by-style/2nd-intermediate-period
# Archaic 39 - https://www.wikiart.org/en/paintings-by-style/archaic-period
# Classical 89 - https://www.wikiart.org/en/paintings-by-style/classical-period
# Hellenistic 135 - https://www.wikiart.org/en/paintings-by-style/hellenistic-period?select=featured
# Geometric 12 - https://www.wikiart.org/en/paintings-by-style/geometric-period
# Early Christian 1 - https://www.wikiart.org/en/paintings-by-style/early-christian
# Early Byzantine (c. 330–750) 109 - https://www.wikiart.org/en/paintings-by-style/early-byzantine-c-330-750
# Middle Byzantine (c. 850–1204) 159 - https://www.wikiart.org/en/paintings-by-style/middle-byzantine-c-850-1204?select=featured
# Mozarabic 85 - https://www.wikiart.org/en/paintings-by-style/mozarabic
# Komnenian style (1081-1185) 48 - https://www.wikiart.org/en/paintings-by-style/komnenian-style-1081-1185
# Latin Empire of Constantinople (1204-1261) 29 - https://www.wikiart.org/en/paintings-by-style/latin-empire-of-constantinople-1204-1261
# Late Byzantine/Palaeologan Renaissance (c. 1261–1453) 137 - https://www.wikiart.org/en/paintings-by-style/late-byzantine-c-1261-1453?select=featured
# Byzantine 256 - https://www.wikiart.org/en/paintings-by-style/byzantine?select=featured
# Macedonian Renaissance (867–1056) 95 - https://www.wikiart.org/en/paintings-by-style/macedonian-renaissance-867-1056
# Romanesque 348 - https://www.wikiart.org/en/paintings-by-style/romanesque?select=featured
# Mosan art 57 - https://www.wikiart.org/en/paintings-by-style/mosan-art
# Gothic 34 - https://www.wikiart.org/en/paintings-by-style/gothic
# International Gothic 329 - https://www.wikiart.org/en/paintings-by-style/international-gothic?select=featured
# Viking art 67 - https://www.wikiart.org/en/paintings-by-style/viking-art
# Medieval Art 25 - https://www.wikiart.org/en/paintings-by-style/medieval-art
# Crusader workshop 13 - https://www.wikiart.org/en/paintings-by-style/crusader-workshop
# Moscow school of icon painting 74 - https://www.wikiart.org/en/paintings-by-style/moscow-school-of-icon-painting
# Cretan school of icon painting 12 - https://www.wikiart.org/en/paintings-by-style/cretan-school-of-icon-painting
# Macedonian school of icon painting 2 - https://www.wikiart.org/en/paintings-by-style/macedonian-school-of-icon-painting
# Coptic art 78 - https://www.wikiart.org/en/paintings-by-style/coptic-art
# Novgorod school of icon painting 31 - https://www.wikiart.org/en/paintings-by-style/novgorod-school-of-icon-painting
# Kyiv school of icon painting 17 - https://www.wikiart.org/en/paintings-by-style/kyiv-school-of-icon-painting
# Vladimir school of icon painting 4 - https://www.wikiart.org/en/paintings-by-style/vladimir-school-of-icon-painting
# Galicia-Volyn school 21 - https://www.wikiart.org/en/paintings-by-style/galicia-volyn-school
# Pskov school of icon painting 6 - https://www.wikiart.org/en/paintings-by-style/pskov-school-of-icon-painting
# Yaroslavl school of icon painting 14 - https://www.wikiart.org/en/paintings-by-style/yaroslavl-school-of-icon-painting
# Vologda school of icon painting 6 - https://www.wikiart.org/en/paintings-by-style/vologda-school-of-icon-painting
# Chernihiv school of icon painting 4 - https://www.wikiart.org/en/paintings-by-style/chernihiv-school-of-icon-painting
# Proto Renaissance 444 - https://www.wikiart.org/en/paintings-by-style/proto-renaissance?select=featured
# Early Renaissance 1877 - https://www.wikiart.org/en/paintings-by-style/early-renaissance?select=featured
# High Renaissance 1769 - https://www.wikiart.org/en/paintings-by-style/high-renaissance?select=featured
# Mannerism (Late Renaissance) 2543 - https://www.wikiart.org/en/paintings-by-style/mannerism-late-renaissance?select=featured
# Northern Renaissance 3275 - https://www.wikiart.org/en/paintings-by-style/northern-renaissance?select=featured
# Renaissance 33 - https://www.wikiart.org/en/paintings-by-style/renaissance
# Baroque 8284 - https://www.wikiart.org/en/paintings-by-style/baroque?select=featured
# Tenebrism 553 - https://www.wikiart.org/en/paintings-by-style/tenebrism?select=featured
# Rococo 3701 - https://www.wikiart.org/en/paintings-by-style/rococo?select=featured
# Classicism 276 - https://www.wikiart.org/en/paintings-by-style/classicism?select=featured
# Neoclassicism 4683 - https://www.wikiart.org/en/paintings-by-style/neoclassicism?select=featured
# Academicism 3043 - https://www.wikiart.org/en/paintings-by-style/academicism?select=featured
# Romanticism 15749 - https://www.wikiart.org/en/paintings-by-style/romanticism?select=featured
# Orientalism 1520 - https://www.wikiart.org/en/paintings-by-style/orientalism?select=featured
# Costumbrismo 121 - https://www.wikiart.org/en/paintings-by-style/costumbrismo?select=featured
# Biedermeier 478 - https://www.wikiart.org/en/paintings-by-style/biedermeier?select=featured
# Neo-Rococo 101 - https://www.wikiart.org/en/paintings-by-style/neo-rococo
# Luminism 402 - https://www.wikiart.org/en/paintings-by-style/luminism?select=featured
# Realism 16884 - https://www.wikiart.org/en/paintings-by-style/realism?select=featured
# Stroganov school of icon painting 1 - https://www.wikiart.org/en/paintings-by-style/stroganov-school-of-icon-painting
# American Realism 375 - https://www.wikiart.org/en/paintings-by-style/american-realism?select=featured
# Naturalism 883 - https://www.wikiart.org/en/paintings-by-style/naturalism?select=featured
# Naïve Art (Primitivism) 3766 - https://www.wikiart.org/en/paintings-by-style/na-ve-art-primitivism?select=featured
# Social Realism 919 - https://www.wikiart.org/en/paintings-by-style/social-realism?select=featured
# Automatic Painting 71 - https://www.wikiart.org/en/paintings-by-style/automatic-painting
# Action painting 110 - https://www.wikiart.org/en/paintings-by-style/action-painting
# Surrealism 7532 - https://www.wikiart.org/en/paintings-by-style/surrealism?select=featured
# Post-Impressionism 8334 - https://www.wikiart.org/en/paintings-by-style/post-impressionism?select=featured
# Symbolism 5480 - https://www.wikiart.org/en/paintings-by-style/symbolism?select=featured
# Metaphysical art 259 - https://www.wikiart.org/en/paintings-by-style/metaphysical-art?select=featured
# Tonalism 391 - https://www.wikiart.org/en/paintings-by-style/tonalism?select=featured
# Impressionism 16839 - https://www.wikiart.org/en/paintings-by-style/impressionism?select=featured
# Magic Realism 1799 - https://www.wikiart.org/en/paintings-by-style/magic-realism?select=featured
# Fantastic Realism 412 - https://www.wikiart.org/en/paintings-by-style/fantastic-realism?select=featured
# Pointillism 591 - https://www.wikiart.org/en/paintings-by-style/pointillism?select=featured
# Divisionism 437 - https://www.wikiart.org/en/paintings-by-style/divisionism?select=featured
# Abstract Art 2037 - https://www.wikiart.org/en/paintings-by-style/abstract-art?select=featured
# Neo-baroque 256 - https://www.wikiart.org/en/paintings-by-style/neo-baroque?select=featured
# Japonism 213 - https://www.wikiart.org/en/paintings-by-style/japonism?select=featured
# Purism 174 - https://www.wikiart.org/en/paintings-by-style/purism?select=featured
# Verism 110 - https://www.wikiart.org/en/paintings-by-style/verism
# Art Deco 1033 - https://www.wikiart.org/en/paintings-by-style/art-deco?select=featured
# Precisionism 362 - https://www.wikiart.org/en/paintings-by-style/precisionism?select=featured
# Cloisonnism 183 - https://www.wikiart.org/en/paintings-by-style/cloisonnism?select=featured
# Regionalism 580 - https://www.wikiart.org/en/paintings-by-style/regionalism?select=featured
# Socialist Realism 755 - https://www.wikiart.org/en/paintings-by-style/socialist-realism?select=featured
# Synthetism 78 - https://www.wikiart.org/en/paintings-by-style/synthetism
# Intimism 112 - https://www.wikiart.org/en/paintings-by-style/intimism
# New Medievialism 11 - https://www.wikiart.org/en/paintings-by-style/new-medievialism
# Fauvism 1230 - https://www.wikiart.org/en/paintings-by-style/fauvism?select=featured
# Muralism 226 - https://www.wikiart.org/en/paintings-by-style/muralism?select=featured
# Art Nouveau (Modern) 7860 - https://www.wikiart.org/en/paintings-by-style/art-nouveau-modern?select=featured
# Cartographic Art 51 - https://www.wikiart.org/en/paintings-by-style/cartographic-art
# Existential Art 39 - https://www.wikiart.org/en/paintings-by-style/existential-art
# Pictorialism 526 - https://www.wikiart.org/en/paintings-by-style/pictorialism?select=featured
# Expressionism 13462 - https://www.wikiart.org/en/paintings-by-style/expressionism?select=featured
# Lettrism 52 - https://www.wikiart.org/en/paintings-by-style/lettrism
# Kitsch 860 - https://www.wikiart.org/en/paintings-by-style/kitsch?select=featured
# Mechanistic Cubism 70 - https://www.wikiart.org/en/paintings-by-style/mechanistic-cubism
# Miserablism 19 - https://www.wikiart.org/en/paintings-by-style/miserablism
# Neo-Romanticism 828 - https://www.wikiart.org/en/paintings-by-style/neo-romanticism?select=featured
# Abstract Expressionism 4985 - https://www.wikiart.org/en/paintings-by-style/abstract-expressionism?select=featured
# Cubism 3461 - https://www.wikiart.org/en/paintings-by-style/cubism?select=featured
# Analytical Cubism 119 - https://www.wikiart.org/en/paintings-by-style/analytical-cubism
# Color Field Painting 1601 - https://www.wikiart.org/en/paintings-by-style/color-field-painting?select=featured
# Hard Edge Painting 639 - https://www.wikiart.org/en/paintings-by-style/hard-edge-painting?select=featured
# Synthetic Cubism 245 - https://www.wikiart.org/en/paintings-by-style/synthetic-cubism?select=featured
# Lyrical Abstraction 1242 - https://www.wikiart.org/en/paintings-by-style/lyrical-abstraction?select=featured
# Orphism 291 - https://www.wikiart.org/en/paintings-by-style/orphism?select=featured
# Indian Space painting 80 - https://www.wikiart.org/en/paintings-by-style/indian-space-painting
# Tubism 22 - https://www.wikiart.org/en/paintings-by-style/tubism
# Cubo-Expressionism 27 - https://www.wikiart.org/en/paintings-by-style/cubo-expressionism
# Figurative Expressionism 369 - https://www.wikiart.org/en/paintings-by-style/figurative-expressionism?select=featured
# Art Informel 1888 - https://www.wikiart.org/en/paintings-by-style/art-informel?select=featured
# Futurism 359 - https://www.wikiart.org/en/paintings-by-style/futurism?select=featured
# Cubo-Futurism 182 - https://www.wikiart.org/en/paintings-by-style/cubo-futurism?select=featured
# Tachisme 576 - https://www.wikiart.org/en/paintings-by-style/tachisme?select=featured
# Neo-Concretism 92 - https://www.wikiart.org/en/paintings-by-style/neo-concretism
# Rayonism 15 - https://www.wikiart.org/en/paintings-by-style/rayonism
# Synchromism 16 - https://www.wikiart.org/en/paintings-by-style/synchromism
# Performance Art 101 - https://www.wikiart.org/en/paintings-by-style/performance-art
# Dada 488 - https://www.wikiart.org/en/paintings-by-style/dada?select=featured
# Transautomatism 83 - https://www.wikiart.org/en/paintings-by-style/transautomatism
# Suprematism 135 - https://www.wikiart.org/en/paintings-by-style/suprematism?select=featured
# Sots Art 16 - https://www.wikiart.org/en/paintings-by-style/sots-art
# Neo-Byzantine 19 - https://www.wikiart.org/en/paintings-by-style/neo-byzantine
# Post-Painterly Abstraction 382 - https://www.wikiart.org/en/paintings-by-style/post-painterly-abstraction?select=featured
# Constructivism 599 - https://www.wikiart.org/en/paintings-by-style/constructivism?select=featured
# Severe Style 10 - https://www.wikiart.org/en/paintings-by-style/severe-style
# Feminist Art 545 - https://www.wikiart.org/en/paintings-by-style/feminist-art?select=featured
# Spectralism 5 - https://www.wikiart.org/en/paintings-by-style/spectralism
# Fiber art 32 - https://www.wikiart.org/en/paintings-by-style/fiber-art
# Modernismo 159 - https://www.wikiart.org/en/paintings-by-style/modernismo?select=featured
# Mail Art 18 - https://www.wikiart.org/en/paintings-by-style/mail-art
# Neo-Suprematism 59 - https://www.wikiart.org/en/paintings-by-style/neo-suprematism
# Analytical Realism 90 - https://www.wikiart.org/en/paintings-by-style/analytical-realism
# Outsider art 492 - https://www.wikiart.org/en/paintings-by-style/outsider-art?select=featured
# Art Brut 503 - https://www.wikiart.org/en/paintings-by-style/art-brut?select=featured
# Neoplasticism 183 - https://www.wikiart.org/en/paintings-by-style/neoplasticism?select=featured
# Concretism 800 - https://www.wikiart.org/en/paintings-by-style/concretism?select=featured
# Neo-Expressionism 1774 - https://www.wikiart.org/en/paintings-by-style/neo-expressionism?select=featured
# Neo-Dada 636 - https://www.wikiart.org/en/paintings-by-style/neo-dada?select=featured
# Perceptism 8 - https://www.wikiart.org/en/paintings-by-style/perceptism
# Neo-Figurative Art 348 - https://www.wikiart.org/en/paintings-by-style/neo-figurative-art?select=featured
# New Realism 457 - https://www.wikiart.org/en/paintings-by-style/new-realism?select=featured
# Kinetic Art 301 - https://www.wikiart.org/en/paintings-by-style/kinetic-art?select=featured
# Spatialism 169 - https://www.wikiart.org/en/paintings-by-style/spatialism?select=featured
# Op Art 1222 - https://www.wikiart.org/en/paintings-by-style/op-art?select=featured
# Pop Art 2893 - https://www.wikiart.org/en/paintings-by-style/pop-art?select=featured
# Nouveau Réalisme 323 - https://www.wikiart.org/en/paintings-by-style/nouveau-r-alisme?select=featured
# Neo-Impressionism 1174 - https://www.wikiart.org/en/paintings-by-style/neo-impressionism?select=featured
# Modernism 74 - https://www.wikiart.org/en/paintings-by-style/modernism-0
# Conceptual Art 2229 - https://www.wikiart.org/en/paintings-by-style/conceptual-art?select=featured
# Minimalism 2244 - https://www.wikiart.org/en/paintings-by-style/minimalism?select=featured
# Post-Minimalism 750 - https://www.wikiart.org/en/paintings-by-style/post-minimalism?select=featured
# Light and Space 441 - https://www.wikiart.org/en/paintings-by-style/light-and-space?select=featured
# Environmental (Land) Art 184 - https://www.wikiart.org/en/paintings-by-style/environmental-land-art?select=featured
# Junk Art 68 - https://www.wikiart.org/en/paintings-by-style/junk-art
# Cyber Art 38 - https://www.wikiart.org/en/paintings-by-style/cyber-art
# Photorealism 411 - https://www.wikiart.org/en/paintings-by-style/photorealism?select=featured
# Hyper-Realism 316 - https://www.wikiart.org/en/paintings-by-style/hyper-realism?select=featured
# Poster Art Realism 54 - https://www.wikiart.org/en/paintings-by-style/poster-art-realism
# Contemporary Realism 1767 - https://www.wikiart.org/en/paintings-by-style/contemporary-realism?select=featured
# P&D (Pattern and Decoration) 153 - https://www.wikiart.org/en/paintings-by-style/p-d-pattern-and-decoration?select=featured
# Transavantgarde 601 - https://www.wikiart.org/en/paintings-by-style/transavantgarde?select=featured
# Confessional Art 120 - https://www.wikiart.org/en/paintings-by-style/confessional-art
# New European Painting 413 - https://www.wikiart.org/en/paintings-by-style/new-european-painting?select=featured
# Neo-Pop Art 902 - https://www.wikiart.org/en/paintings-by-style/neo-pop-art?select=featured
# Neo-Geo 139 - https://www.wikiart.org/en/paintings-by-style/neo-geo?select=featured
# Maximalism 62 - https://www.wikiart.org/en/paintings-by-style/maximalism
# Neo-Orthodoxism 21 - https://www.wikiart.org/en/paintings-by-style/neo-orthodoxism
# Graffiti Art 1 - https://www.wikiart.org/en/paintings-by-style/graffiti-art
# Street art 376 - https://www.wikiart.org/en/paintings-by-style/street-art?select=featured
# Lowbrow Art 109 - https://www.wikiart.org/en/paintings-by-style/lowbrow-art
# Stuckism 79 - https://www.wikiart.org/en/paintings-by-style/stuckism
# New Casualism 49 - https://www.wikiart.org/en/paintings-by-style/new-casualism
# Art Singulier 23 - https://www.wikiart.org/en/paintings-by-style/art-singulier
# Superflat 30 - https://www.wikiart.org/en/paintings-by-style/superflat
# Excessivism 29 - https://www.wikiart.org/en/paintings-by-style/excessivism
# Digital Art 246 - https://www.wikiart.org/en/paintings-by-style/digital-art?select=featured
# Hyper-Mannerism (Anachronism) 17 - https://www.wikiart.org/en/paintings-by-style/hyper-mannerism-anachronism
# Neo-Minimalism 312 - https://www.wikiart.org/en/paintings-by-style/neo-minimalism?select=featured
# Fantasy Art 126 - https://www.wikiart.org/en/paintings-by-style/fantasy-art?select=featured
# Sky Art 3 - https://www.wikiart.org/en/paintings-by-style/sky-art
# Contemporary 1228 - https://www.wikiart.org/en/paintings-by-style/contemporary?select=featured
# Site-specific art 11 - https://www.wikiart.org/en/paintings-by-style/site-specific-art
# New media art 6 - https://www.wikiart.org/en/paintings-by-style/new-media-art
# Classical Realism 226 - https://www.wikiart.org/en/paintings-by-style/classical-realism?select=featured
# Postcolonial art 320 - https://www.wikiart.org/en/paintings-by-style/postcolonial-art?select=featured
# Queer art 57 - https://www.wikiart.org/en/paintings-by-style/queer-art
# Gongbi 35 - https://www.wikiart.org/en/paintings-by-style/gongbi
# Ink and wash painting 821 - https://www.wikiart.org/en/paintings-by-style/ink-and-wash-painting?select=featured
# Joseon Dynasty 33 - https://www.wikiart.org/en/paintings-by-style/joseon-dynasty
# Shin-hanga 425 - https://www.wikiart.org/en/paintings-by-style/shin-hanga?select=featured
# Sōsaku hanga 480 - https://www.wikiart.org/en/paintings-by-style/s-saku-hanga?select=featured
# Sumi-e (Suiboku-ga) 126 - https://www.wikiart.org/en/paintings-by-style/suiboku-ga-0?select=featured
# Ukiyo-e 1859 - https://www.wikiart.org/en/paintings-by-style/ukiyo-e?select=featured
# Yamato-e 47 - https://www.wikiart.org/en/paintings-by-style/yamato-e
# Kanō school style 15 - https://www.wikiart.org/en/paintings-by-style/kano-school
# Nanga (Bunjinga) 58 - https://www.wikiart.org/en/paintings-by-style/nanga-bunjinga
# Nihonga 48 - https://www.wikiart.org/en/paintings-by-style/nihonga
# Zen 166 - https://www.wikiart.org/en/paintings-by-style/zen?select=featured
# Ero guro 17 - https://www.wikiart.org/en/paintings-by-style/ero-guro-14
# Abbasid Period 16 - https://www.wikiart.org/en/paintings-by-style/abbasid-period
# Ilkhanid 14 - https://www.wikiart.org/en/paintings-by-style/ilkhanid
# Nas-Taliq 14 - https://www.wikiart.org/en/paintings-by-style/nas-taliq
# Timurid Period 51 - https://www.wikiart.org/en/paintings-by-style/timurid-period
# Mughal 16 - https://www.wikiart.org/en/paintings-by-style/mughal
# Ottoman Period 80 - https://www.wikiart.org/en/paintings-by-style/ottoman-period
# Safavid Period 130 - https://www.wikiart.org/en/paintings-by-style/safavid-period?select=featured
# Native Art 569 - https://www.wikiart.org/en/paintings-by-style/native-art?select=featured
# Yoruba 28 - https://www.wikiart.org/en/paintings-by-style/yoruba
# Folk art 24 - https://www.wikiart.org/en/paintings-by-style/folk-art
# Post-classic (c.900-1580) 99 - https://www.wikiart.org/en/paintings-by-style/post-classic-c-900-1580
# New Ink Painting 64 - https://www.wikiart.org/en/paintings-by-style/new-ink-painting
# Documentary photography 158 - https://www.wikiart.org/en/paintings-by-style/documentary-photography?select=featured
# Street Photography 141 - https://www.wikiart.org/en/paintings-by-style/street-photography?select=featured

# %% [markdown]
# Collect each artwork page links from each style page collected above.

# %%
driver = webdriver.Chrome()
artwork_links_by_style = {}

for style_url in style_urls:
    try:
        driver.get(style_url)
        time.sleep(2)

        # Keep clicking "LOAD MORE" if available
        while True:
            try:
                load_more_btn = driver.find_element(By.CSS_SELECTOR, "a.masonry-load-more-button")
                driver.execute_script("arguments[0].scrollIntoView(true);", load_more_btn)
                time.sleep(1)
                load_more_btn.click()
                time.sleep(2)
            except (NoSuchElementException, ElementClickInterceptedException, ElementNotInteractableException):
                break
            except UnexpectedAlertPresentException:
                alert = driver.switch_to.alert
                print(f"Alert appeared on {style_url}, accepting and continuing.")
                alert.accept()
                time.sleep(2)
                continue  # Try clicking again

        # Once all loaded, collect artwork links
        artwork_elements = driver.find_elements(By.CSS_SELECTOR, 'a.artwork-name')
        artwork_links = [a.get_attribute('href') for a in artwork_elements if a.get_attribute('href')]

        artwork_links_by_style[style_url] = artwork_links

    except UnexpectedAlertPresentException:
        # Handle unexpected alerts during page load
        alert = driver.switch_to.alert
        print(f"Alert during loading {style_url}, accepting and skipping.")
        alert.accept()
        continue
    except Exception as e:
        print(f"Error on {style_url}: {e}")
        continue

# %%
# Save to txt file
with open("artwork_links_by_style.txt", "w", encoding="utf-8") as f:
    for style_url, links in artwork_links_by_style.items():
        f.write(f"Style URL: {style_url}\n")
        for link in links:
            f.write(f"  {link}\n")
        f.write("\n")  # separate styles

# %% [markdown]
# Filter out the styles with less that 500 artworks in total

# %%
input_path = "artwork_links_by_style_eddited.txt"
output_path = "artwork_links_filtered.txt"

filtered_data = {}
current_style = None

with open(input_path, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if line.startswith("Style URL:"):
            current_style = line[len("Style URL:"):].strip()
            filtered_data[current_style] = []
        elif line.startswith("http") and current_style:
            filtered_data[current_style].append(line)

# Filter styles with at least 500 artworks
filtered_data = {style: links for style, links in filtered_data.items() if len(links) >= 500}

# Save the filtered data
with open(output_path, "w", encoding="utf-8") as f:
    for style, links in filtered_data.items():
        f.write(f"Style URL: {style}\n")
        for link in links:
            f.write(f"  {link}\n")
        f.write("\n")

print(f"Saved filtered styles (≥500 artworks) to: {output_path}")
# Out:
# Saved filtered styles (≥500 artworks) to: artwork_links_filtered.txt

# %%
#file_path = "artwork_links_filtered.txt"
file_path = "artwork_links_by_style_eddited.txt"

style_names = []

with open(file_path, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if line.startswith("Style URL:"):
            style_url = line[len("Style URL:"):].strip()
            style_names.append(style_url)

# Print results
print(f"Total styles: {len(style_names)}\n")
# Out:
# Total styles: 190

# %%
file_path = "artwork_links_filtered.txt"

style_counts = {}
current_style = None

with open(file_path, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if line.startswith("Style URL:"):
            current_style = line[len("Style URL:"):].strip()
            style_counts[current_style] = 0
        elif line.startswith("http") and current_style:
            style_counts[current_style] += 1

# Compute min and max
min_count = min(style_counts.values())
max_count = max(style_counts.values())

# Get styles with those counts
min_styles = [style for style, count in style_counts.items() if count == min_count]
max_styles = [style for style, count in style_counts.items() if count == max_count]

# Print results
print(f"Maximum artwork count: {max_count}")
for s in max_styles:
    print(f"  ↳ Style with max count: {s}")

print(f"\nMinimum artwork count: {min_count}")
for s in min_styles:
    print(f"  ↳ Style with min count: {s}")
# Out:
# Maximum artwork count: 3600
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/baroque?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/rococo?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/neoclassicism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/romanticism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/realism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/na-ve-art-primitivism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/surrealism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/post-impressionism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/symbolism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/impressionism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/art-nouveau-modern?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/expressionism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/abstract-expressionism?select=featured
#
# Minimum artwork count: 503
#   ↳ Style with min count: https://www.wikiart.org/en/paintings-by-style/art-brut?select=featured

# %%
file_path = "artwork_links_by_style.txt"

style_counts = {}
current_style = None

with open(file_path, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if line.startswith("Style URL:"):
            current_style = line[len("Style URL:"):].strip()
            style_counts[current_style] = 0
        elif line.startswith("http") and current_style:
            style_counts[current_style] += 1

# Compute min and max
min_count = min(style_counts.values())
max_count = max(style_counts.values())

# Get styles with those counts
min_styles = [style for style, count in style_counts.items() if count == min_count]
max_styles = [style for style, count in style_counts.items() if count == max_count]

# Print results
print(f"Maximum artwork count: {max_count}")
for s in max_styles:
    print(f"  ↳ Style with max count: {s}")

print(f"\nMinimum artwork count: {min_count}")
for s in min_styles:
    print(f"  ↳ Style with min count: {s}")
# Out:
# Maximum artwork count: 3600
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/baroque?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/rococo?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/neoclassicism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/romanticism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/realism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/na-ve-art-primitivism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/surrealism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/post-impressionism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/symbolism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/impressionism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/art-nouveau-modern?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/expressionism?select=featured
#   ↳ Style with max count: https://www.wikiart.org/en/paintings-by-style/abstract-expressionism?select=featured
#
# Minimum artwork count: 1
#   ↳ Style with min count: https://www.wikiart.org/en/paintings-by-style/old-kingdom
#   ↳ Style with min count: https://www.wikiart.org/en/paintings-by-style/2nd-intermediate-period
#   ↳ Style with min count: https://www.wikiart.org/en/paintings-by-style/early-christian
#   ↳ Style with min count: https://www.wikiart.org/en/paintings-by-style/stroganov-school-of-icon-painting
#   ↳ Style with min count: https://www.wikiart.org/en/paintings-by-style/graffiti-art

# %%
# Load filtered artwork links from file (ignoring style URLs)
with open("artwork_links_filtered.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()

# Filter only artwork links (not style URLs)
artwork_links = [line.strip() for line in lines if line.startswith("  http") and not line.startswith("Style URL")]

print(len(artwork_links))
# Out:
# 96498

# %% [markdown]
# Collect the information (features and image link which will be used to download the image later) from collected artwork page links

# %%
# Output file
csv_file = "artwork_details.csv"
excel_file = "artwork_details.xlsx"

# Load already scraped data (if exists)    
if os.path.exists(csv_file) and os.path.getsize(csv_file) > 0:
    existing_df = pd.read_csv(csv_file)
    scraped_urls = set(existing_df["url"])
    all_data = existing_df.to_dict(orient="records")
else:
    scraped_urls = set()
    all_data = []

# Setup Selenium
driver = webdriver.Chrome()

# Helper function to safely get element text
def safe_find(by, value):
    try:
        return driver.find_element(by, value).text.strip()
    except NoSuchElementException:
        return None

# Scrape each URL (skip if already scraped)
for url in artwork_links:
    if url in scraped_urls:
        continue

    try:
        driver.get(url)
        time.sleep(0.5)

        data = {
            "url": url,
            "artwork_name": safe_find(By.TAG_NAME, "h3"),
            "artist_name": safe_find(By.CSS_SELECTOR, "h5[itemprop='creator'] span[itemprop='name']"),
            "date": safe_find(By.CSS_SELECTOR, "span[itemprop='dateCreated']"),
            "style": safe_find(By.XPATH, "//li[s/text()='Style:']/span"),
            "genre": safe_find(By.XPATH, "//li[s/text()='Genre:']//span[@itemprop='genre']"),
            "media": ", ".join(
                [e.text.strip() for e in driver.find_elements(By.XPATH, "//li[s/text()='Media:']/span/a")]
            ) or None,
            "tags": ", ".join(
                [e.text.strip() for e in driver.find_elements(By.CSS_SELECTOR, ".tags-cheaps__item__ref")]
            ) or None,
            "image_url": driver.find_element(By.CSS_SELECTOR, "img[itemprop='image']").get_attribute("src")
                if driver.find_elements(By.CSS_SELECTOR, "img[itemprop='image']") else None
        }

        all_data.append(data)
        scraped_urls.add(url)

        # Save after each artwork
        df = pd.DataFrame(all_data)
        df.to_csv(csv_file, index=False, encoding="utf-8")
        df.to_excel(excel_file, index=False)

        print(f"✅ Scraped and saved: {url}")

    except Exception as e:
        print(f"❌ Error with {url}: {e}")
        continue

# Close browser
driver.quit()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_24516\2740235301.py:14: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   existing_df = pd.read_csv(csv_file)
# ✅ Scraped and saved: https://www.wikiart.org/en/georges-valmier/place-du-village-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/georges-valmier/still-life-in-front-of-a-window-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/georges-valmier/still-life-in-front-of-the-window-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/georges-valmier/the-village-fun-fair-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/gustave-buchet/composition-avec-7-tubes-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/vytautas-kairiukstis/laivelis-ant-ezero-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/carlos-quizpez-asin/nocturno-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/paul-nash/the-stackyard-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/jindrich-styrsky/namesicna-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/jindrich-styrsky/kominik-a-snehulak-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/josef-capek/sasek-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/henryk-streng/hairdresser-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/henryk-streng/syclist-1925
# ✅ Scraped and saved: https://www.wikiart.org/en/roger-de-la-fresnaye/the-table-louis-philippe
# ✅ Scraped and saved: https://www.wikiart.org/en/georges-braque/the-bowl-of-grapes-1926
# ✅ Scraped and saved: https://www.wikiart.org/en/fernand-leger/red-pot-1926
# ✅ Scraped and saved: https://www.wikiart.org/en/marc-chagall/three-acrobates-1926
# ✅ Scraped and saved: https://www.wikiart.org/en/juan-gris/bananas
# ✅ Scraped and saved: https://www.wikiart.org/en/juan-gris/fruit-with-bowl-1926
# ✅ Scraped and saved: https://www.wikiart.org/en/juan-gris/the-musician-s-table-1926
# ✅ Scraped and saved: https://www.wikiart.org/en/juan-gris/the-reader-1926
# ✅ Scraped and saved: https://www.wikiart.org/en/juan-gris/the-table-in-front-of-the-picture-1926
# ✅ Scraped and saved: https://www.wikiart.org/en/salvador-dali/cubist-figure
# ✅ Scraped and saved: https://www.wikiart.org/en/salvador-dali/cubist-self-portrait
# ✅ Scraped and saved: https://www.wikiart.org/en/salvador-dali/figure-on-the-rocks
# ✅ Scraped and saved: https://www.wikiart.org/en/salvador-dali/figures-lying-on-the-sand
# ✅ Scraped and saved: https://www.wikiart.org/en/salvador-dali/homage-to-erik-satie
# ✅ Scraped and saved: https://www.wikiart.org/en/salvador-dali/neo-cubist-academy-composition-with-three-figures
# ✅ Scraped and saved: https://www.wikiart.org/en/salvador-dali
# ✅ Scraped and saved: https://www.wikiart.org/en/li-chevalier/incommensurable-2021
# ✅ Scraped and saved: https://www.wikiart.org/en/li-chevalier/vestiges-2021
# ✅ Scraped and saved: https://www.wikiart.org/en/albert-rafols-casamada/blau-profund-1858
# ✅ Scraped and saved: https://www.wikiart.org/en/modest-cuixart/natura-aurea-1900
# ✅ Scraped and saved: https://www.wikiart.org/en/shozo-shimamoto/unknown-title
# ✅ Scraped and saved: https://www.wikiart.org/en/se-ok-suh/ducks
# ✅ Scraped and saved: https://www.wikiart.org/en/se-ok-suh/people
# ✅ Scraped and saved: https://www.wikiart.org/en/luis-feito/471
# ✅ Scraped and saved: https://www.wikiart.org/en/luis-feito/597
# ✅ Scraped and saved: https://www.wikiart.org/en/luis-feito/composition-i
# ✅ Scraped and saved: https://www.wikiart.org/en/luis-feito/painting-488
# ✅ Scraped and saved: https://www.wikiart.org/en/luis-feito/painting-847
# ✅ Scraped and saved: https://www.wikiart.org/en/luis-feito/painting-139
# ✅ Scraped and saved: https://www.wikiart.org/en/luis-feito/sin-t-tulo-abstracci-n-en-roso-y-negro
# ✅ Scraped and saved: https://www.wikiart.org/en/luis-feito/untitled
# ✅ Scraped and saved: https://www.wikiart.org/en/luis-feito/untitled-1
# ✅ Scraped and saved: https://www.wikiart.org/en/samuel-buri/abstract-composition-1
# ✅ Scraped and saved: https://www.wikiart.org/en/samuel-buri/untitled
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/o-sentir-da-paisagem-vi
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/dizeres-intimos-i
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/cones-enigm-ticos-ii
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/intervalos-no-tempo-i
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/leitura-branca-i
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/musica-de-tempo-ii
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/nocturno-de-veneza-i
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/passagem-dos-corpos-vi
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/sonhos-e-paix-es-ii
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/unknown-title
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/m-stica-do-tempo-ii
# ✅ Scraped and saved: https://www.wikiart.org/en/gil-teixeira-lopes/espa-o-dourado
# ✅ Scraped and saved: https://www.wikiart.org/en/matsutani/bird
# ✅ Scraped and saved: https://www.wikiart.org/en/matsutani/ry-d-flowing
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/ardoise
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/ardoise-1
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/ardoise-2
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/arrachement
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/arrachement-1
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/arrachement-2
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/arrachement-3
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/carte
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/carte-1
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/carte-2
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/carte-3
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/carte-4
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/carte-5
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/collage
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/collage-1
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/collage-2
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/collage-3
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/collage-4
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/collage-5
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/collage-6
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/colonne-du-ciel
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/les-colonnes-du-ciel
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/ficelage-1
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/ficelage-2
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/froissage
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/froissage-1
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/m-t-orite
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/m-t-orite-1
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/m-t-orite-2
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/pochoir
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/pochoir-1
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/pochoir-2
# ✅ Scraped and saved: https://www.wikiart.org/en/andre-pierre-arnal/pochoir-3
# ✅ Scraped and saved: https://www.wikiart.org/en/asger-jorn/sm-ting-1940
# ✅ Scraped and saved: https://www.wikiart.org/en/wols/camp-des-milles-1940
# ✅ Scraped and saved: https://www.wikiart.org/en/wols/untitled-1940
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-fautrier/la-juive-1943
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-fautrier/otage-1943
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-fautrier/untitled-1943
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-michel-atlan/untitled-1943
# ✅ Scraped and saved: https://www.wikiart.org/en/asger-jorn/vision-rouge-1944
# ✅ Scraped and saved: https://www.wikiart.org/en/wols/don-juan-1944
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-rene-bazaine/jeanne-d-arc-1944
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-fautrier/t-te-d-otage-no-14-head-of-a-hostage-no-14-1944
# ✅ Scraped and saved: https://www.wikiart.org/en/willi-baumeister/sun-figures-1944
# ✅ Scraped and saved: https://www.wikiart.org/en/maurice-esteve/le-napperon-1944
# ✅ Scraped and saved: https://www.wikiart.org/en/lennart-rodhe/sk-despelerskan-1944
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-fautrier/tete-dotage-1944
# ✅ Scraped and saved: https://www.wikiart.org/en/asger-jorn/didaska-i-1945
# ✅ Scraped and saved: https://www.wikiart.org/en/alfred-manessier/figure-of-piety-1945
# ✅ Scraped and saved: https://www.wikiart.org/en/alfred-manessier/salve-regina-1945
# ✅ Scraped and saved: https://www.wikiart.org/en/wols/cite-1945
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-rene-bazaine/figure-sur-fond-d-arbre-1945
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-fautrier/d-pouille-1945
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-fautrier/oradour-sur-glane-1945
# ✅ Scraped and saved: https://www.wikiart.org/en/wols/untitled-cathedral-1945
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-fautrier/otage-ndeg3-1945
# ✅ Scraped and saved: https://www.wikiart.org/en/asger-jorn/la-fleur-du-mal-1946
# ✅ Scraped and saved: https://www.wikiart.org/en/karel-appel/little-moon-men-1946
# ✅ Scraped and saved: https://www.wikiart.org/en/alfred-manessier/untitled-1946
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-rene-bazaine/houses-in-saint-guenole-1946
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-rene-bazaine/lecielduplicate-1902
# ✅ Scraped and saved: https://www.wikiart.org/en/willi-baumeister/the-prophet-and-herodias-1946
# ✅ Scraped and saved: https://www.wikiart.org/en/joan-ponc/untitled-1946
# ✅ Scraped and saved: https://www.wikiart.org/en/joan-ponc/untitled-1946-1
# ✅ Scraped and saved: https://www.wikiart.org/en/joan-ponc/untitled-1946-3
# ✅ Scraped and saved: https://www.wikiart.org/en/joan-ponc/untitled-1946-4
# ✅ Scraped and saved: https://www.wikiart.org/en/nicolas-de-sta-l/composition-1947
# ✅ Scraped and saved: https://www.wikiart.org/en/nicolas-de-sta-l/composition-1947-1
# ✅ Scraped and saved: https://www.wikiart.org/en/alfred-manessier/angelus-domini-nuntiavit-mari-1947
# ✅ Scraped and saved: https://www.wikiart.org/en/wols/composition-1947
# ✅ Scraped and saved: https://www.wikiart.org/en/wols/le-tourbillon-1947
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-rene-bazaine/the-actors-1947
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-rene-bazaine/the-big-tree-in-the-country-trees-and-plains-1947
# ✅ Scraped and saved: https://www.wikiart.org/en/roger-bissi-re/la-chanson-des-rues-1947
# ✅ Scraped and saved: https://www.wikiart.org/en/jean-fautrier/hostages-black-ground-1947
# ✅ Scraped and saved: https://www.wikiart.org/en/willi-baumeister/shamash-told-us-to-fight-against-chumbaba-1947
# ✅ Scraped and saved: https://www.wikiart.org/en/jacques-busse/etang-la-nuit-1947
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 63
#      61     df = pd.DataFrame(all_data)
#      62     df.to_csv(csv_file, index=False, encoding="utf-8")
# ---> 63     df.to_excel(excel_file, index=False)
#      65     print(f"✅ Scraped and saved: {url}")
#      67 except Exception as e:
#
# File c:\Users\User\Desktop\476 data mining\HW\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\User\Desktop\476 data mining\HW\.venv\Lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)   2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File c:\Users\User\Desktop\476 data mining\HW\.venv\Lib\site-packages\pandas\io\formats\excel.py:952, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     949     need_save = True
#     951 try:
# --> 952     writer._write_cells(
#     953         formatted_cells,
#     954         sheet_name,
#     955         startrow=startrow,
#     956         startcol=startcol,
#     957         freeze_panes=freeze_panes,
#     958     )
#     959 finally:
#     960     # make sure to close opened file handles
#     961     if need_save:
#
# File c:\Users\User\Desktop\476 data mining\HW\.venv\Lib\site-packages\pandas\io\excel\_openpyxl.py:487, in OpenpyxlWriter._write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     482     wks.freeze_panes = wks.cell(
#     483         row=freeze_panes[0] + 1, column=freeze_panes[1] + 1
#     484     )
#     486 for cell in cells:
# --> 487     xcell = wks.cell(
#     488         row=startrow + cell.row + 1, column=startcol + cell.col + 1
#     489     )
#     490     xcell.value, fmt = self._value_with_fmt(cell.val)
#     491     if fmt:
#
# File c:\Users\User\Desktop\476 data mining\HW\.venv\Lib\site-packages\openpyxl\worksheet\worksheet.py:244, in Worksheet.cell(self, row, column, value)
#     241 if row < 1 or column < 1:
#     242     raise ValueError("Row or column values must be at least 1")
# --> 244 cell = self._get_cell(row, column)
#     245 if value is not None:
#     246     cell.value = value
#
# File c:\Users\User\Desktop\476 data mining\HW\.venv\Lib\site-packages\openpyxl\worksheet\worksheet.py:260, in Worksheet._get_cell(self, row, column)
#     258 coordinate = (row, column)
#     259 if not coordinate in self._cells:
# --> 260     cell = Cell(self, row=row, column=column)
#     261     self._add_cell(cell)
#     262 return self._cells[coordinate]
#
# File c:\Users\User\Desktop\476 data mining\HW\.venv\Lib\site-packages\openpyxl\cell\cell.py:109, in Cell.__init__(self, worksheet, row, column, value, style_array)
#     108 def __init__(self, worksheet, row=None, column=None, value=None, style_array=None):
# --> 109     super().__init__(worksheet, style_array)
#     110     self.row = row
#     111     """Row number of this cell (1-based)"""
#
# File c:\Users\User\Desktop\476 data mining\HW\.venv\Lib\site-packages\openpyxl\styles\styleable.py:132, in StyleableObject.__init__(self, sheet, style_array)
#     128 pivotButton = StyleArrayDescriptor('pivotButton')
#     130 __slots__ = ('parent', '_style')
# --> 132 def __init__(self, sheet, style_array=None):
#     133     self.parent = sheet
#     134     if style_array is not None:
#
# KeyboardInterrupt:
